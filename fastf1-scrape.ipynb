# %%
import fastf1
import pandas as pd
import os
import time
import logging
from datetime import datetime

# %%
CACHE_DIR = 'fastf1_cache'
SAVE_DIR = 'f1_data_csvs'
START_YEAR = 2018          # F1 timing/telemetry data generally available from 2018
END_YEAR = datetime.now().year
SESSIONS_TO_GET = ['FP1', 'FP2', 'FP3', 'Q', 'S', 'SQ', 'R'] # Common sessions (Sprint='S', Sprint Quali='SQ')
DELAY_SECONDS = 1         # Delay between processing sessions to be polite to API

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

try:
    fastf1.Cache.enable_cache(CACHE_DIR)
    logging.info(f"FastF1 cache enabled at: {CACHE_DIR}")
except Exception as e:
    logging.error(f"Error enabling FastF1 cache: {e}")


os.makedirs(SAVE_DIR, exist_ok=True)
logging.info(f"CSV data will be saved in: {SAVE_DIR}")
# Out:
# 2025-05-17 12:41:06,240 - ERROR - Error enabling FastF1 cache: Cache directory does not exist! Please check for typos or create it first.
# 2025-05-17 12:41:06,241 - INFO - CSV data will be saved in: f1_data_csvs

# %%
import glob
# SESSIONS_TO_GET = ['R']
SESSIONS_TO_GET = ['FP1', 'FP2', 'FP3', 'Q', 'S', 'SQ', 'R']
TMP_PATH = 'airflow/tmp/fastf1-data'
year = 2020
round = 2
event = fastf1.get_event(year, round)
print(event["EventName"])
event_name = event['EventName']
event_round = event['RoundNumber']
logging.info(f"Processing Event: {year} - Round {event_round} - {event_name}")

lap_dfs = []
for session_name in SESSIONS_TO_GET:
    logging.debug(f"Attempting Session: {session_name}")
    session_identifier = f"{year}_{event_round:02d}_{event_name}_{session_name}"

    try:
        session = fastf1.get_session(year, event_name, session_name)

        session.load(laps=True, weather=True, messages=True, telemetry=True)
        logging.info(f"Loaded basic data for {session_identifier}")

        # precise telemetry is in car_data, pos_data, etc.
        # Check https://docs.fastf1.dev/core.html#fastf1.core.Session for more info
        os.makedirs(TMP_PATH, exist_ok=True)

        if hasattr(session, 'laps') and not session.laps.empty:
            lap_dfs.append(session.laps)
            logging.debug(f"Saved laps for {session_identifier}")

            sess_tel_dfs = []
            telemetry_saved = False
            for drv_id in session.drivers:
                try:
                    drv_laps = session.laps.pick_drivers(drv_id)
                    if not drv_laps.empty:
                        drv_abbr = drv_laps['Driver'].iloc[0]
                        drv_tel = drv_laps.get_telemetry()

                        if not drv_tel.empty:
                            drv_tel = drv_tel.merge(drv_laps[['LapNumber', 'Time']], on='Time', how='left')
                            drv_tel['DriverId'] = drv_id
                            drv_tel['Year'] = year
                            drv_tel['Round'] = event_round
                            drv_tel['Session'] = session

                            sess_tel_dfs.append(drv_tel)
                            logging.debug(f"Saved telemetry for driver {drv_abbr} in {session_identifier} with shape {drv_tel.shape}")
                            telemetry_saved = True
                        else:
                            logging.debug(f"No telemetry data returned for driver {drv_abbr} in {session_identifier}")
                except Exception as tel_ex:
                    logging.warning(f"Could not get/save telemetry for driver {drv_id} in {session_identifier}: {tel_ex}")
            if telemetry_saved:
                logging.info(f"Finished processing telemetry for {session_identifier}")
            else:
                logging.info(f"No telemetry saved for any driver in {session_identifier}")

            sess_tel_dfs_concat = pd.concat(sess_tel_dfs, ignore_index=True)
            sess_tel_dfs_concat.to_csv(os.path.join(TMP_PATH, f'telemetry_{session_identifier}.csv'))
    except Exception as e:
        pass

sess_lap_dfs_concat = pd.concat(lap_dfs, ignore_index=True)
sess_lap_dfs_concat.to_csv(os.path.join(TMP_PATH, f"laps_{year}_{round}.csv"))

telemetry_files = glob.glob(os.path.join(TMP_PATH, 'telemetry_*.csv'))
tel_dfs = []

for tel_file in telemetry_files:
    try:
        tel_file_split = os.path.splitext(os.path.basename(tel_file))[0].split('_')
        if int(tel_file_split[1]) == year and int(tel_file_split[2]) == round:
            df_tel = pd.read_csv(tel_file)
            tel_dfs.append(df_tel)

    except Exception as e:
        logging.warning(f"Could not normalize telemetry file {tel_file}: {e}")

df_concat = pd.concat(tel_dfs, ignore_index=True)
df_concat.drop(df_concat.columns[[0]], axis=1, inplace=True)
df_concat.to_csv(os.path.join(TMP_PATH, f'telemetry_{year}_{round}.csv'))

logging.info(f"Normalized telemetry saved for {event_name} with shape {df_concat.shape}")
# Out:
# 2025-05-17 12:47:23,219 - INFO - Processing Event: 2020 - Round 2 - Styrian Grand Prix
# Styrian Grand Prix
# 2025-05-17 12:48:02,530 - INFO - Normalized telemetry saved for Styrian Grand Prix with shape (2971902, 23)

# %%
# --- Main Loop ---
for year in range(START_YEAR, END_YEAR + 1):
    logging.debug(f"--- Processing Year: {year} ---", )
    try:
        schedule = fastf1.get_event_schedule(year)
        # Convert EventDate to datetime objects to filter past events if needed
        # schedule['EventDate'] = pd.to_datetime(schedule['EventDate']).dt.date
        # schedule = schedule[schedule['EventDate'] < datetime.now().date()] # Optional: Only process past events

    except Exception as e:
        logging.error(f"Could not get event schedule for {year}: {e}")
        continue

    for index, event in schedule.iterrows():
        event_name = event['EventName']
        event_round = event['RoundNumber']
        logging.info(f"Processing Event: {year} - Round {event_round} - {event_name}")

        for session_name in SESSIONS_TO_GET:
            logging.debug(f"Attempting Session: {session_name}")
            session_identifier = f"{year}_{event_round:02d}_{event_name}_{session_name}" # Unique ID for logging/paths
            session_save_path = os.path.join(SAVE_DIR, str(year), f"{event_round:02d}_{event_name}", session_name)

            # # Check if all expected CSVs exist for this session, skip if so
            # expected_files = ['laps.csv', 'results.csv', 'weather.csv', 'messages.csv']
            # csvs_exist = all(os.path.exists(os.path.join(session_save_path, fname)) for fname in expected_files)

            # # Check for at least one telemetry file (since driver list may change)
            # telemetry_files_exist = any(
            #     fname.startswith('telemetry_') and fname.endswith('.csv')
            #     for fname in os.listdir(session_save_path) if os.path.isdir(session_save_path)
            # ) if os.path.isdir(session_save_path) else False

            # if csvs_exist and telemetry_files_exist:
            #     logging.info(f"All CSVs already exist for {session_identifier}, skipping session.")
            #     continue
            try:
                session = fastf1.get_session(year, event_name, session_name)

                session.load(laps=True, weather=True, messages=True, telemetry=True)
                logging.info(f"Loaded basic data for {session_identifier}")

                os.makedirs(session_save_path, exist_ok=True)

                if hasattr(session, 'laps') and not session.laps.empty:
                    session.laps.to_csv(os.path.join(session_save_path, 'laps.csv'), index=False)
                    logging.debug(f"Saved laps for {session_identifier}")

                    logging.info(f"Loading telemetry for {session_identifier}...")
                    telemetry_saved = False
                    for drv_id in session.drivers: # Iterate through driver numbers
                        try:
                            drv_laps = session.laps.pick_drivers(drv_id)
                            if not drv_laps.empty:
                                drv_abbr = drv_laps['Driver'].iloc[0]
                                drv_tel = drv_laps.get_telemetry()

                                if not drv_tel.empty:
                                    drv_tel = drv_tel.merge(drv_laps[['LapNumber', 'SessionTime']], on='SessionTime', how='left')

                                    drv_tel.to_csv(os.path.join(session_save_path, f'telemetry_{drv_abbr}.csv'), index=False)
                                    logging.debug(f"Saved telemetry for driver {drv_abbr} in {session_identifier}")
                                    telemetry_saved = True
                                else:
                                     logging.debug(f"No telemetry data returned for driver {drv_abbr} in {session_identifier}")

                        except Exception as tel_ex:
                            logging.warning(f"Could not get/save telemetry for driver {drv_id} in {session_identifier}: {tel_ex}")
                    if telemetry_saved:
                         logging.info(f"Finished processing telemetry for {session_identifier}")
                    else:
                         logging.info(f"No telemetry saved for any driver in {session_identifier}")


                if hasattr(session, 'results') and not session.results.empty:
                    session.results.to_csv(os.path.join(session_save_path, 'results.csv'), index=False)
                    logging.debug(f"Saved results for {session_identifier}")

                if hasattr(session, 'weather_data') and not session.weather_data.empty:
                    session.weather_data.to_csv(os.path.join(session_save_path, 'weather.csv'), index=False)
                    logging.debug(f"Saved weather for {session_identifier}")

                if hasattr(session, 'messages') and not session.messages.empty:
                    session.messages.to_csv(os.path.join(session_save_path, 'messages.csv'), index=False)
                    logging.debug(f"Saved messages for {session_identifier}")

                logging.info(f"Successfully processed and saved data for {session_identifier}")

            # except fastf1.core.SessionNotAvailableError:
            #      logging.warning(f"Session {session_name} not available or does not exist for {year} {event_name}. Skipping.")
            except fastf1.core.DataNotLoadedError as e:
                logging.error(f"Data not loaded for {session_identifier}. Might be too recent or unavailable. Error: {e}")
            except ConnectionError as e:
                 logging.error(f"Connection error during {session_identifier}: {e}. Check network.")
                 time.sleep(10) # Longer sleep on connection error
            except Exception as e:
                # Catch other potential errors (API issues, unexpected data format, etc.)
                logging.error(f"An unexpected error occurred for {session_identifier}: {e.__class__.__name__} - {e}")

            finally:
                # Add a delay after processing each session regardless of success/failure
                logging.debug(f"Waiting {DELAY_SECONDS} seconds before next session...")
                time.sleep(DELAY_SECONDS)

    logging.info(f"--- Finished Processing Year: {year} ---")

logging.info("--- All Years Processed ---")
# Out:
# 2025-05-05 22:45:06,566 - INFO - Processing Event: 2018 - Round 1 - Australian Grand Prix
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.5.3]
# 2025-05-05 22:45:06,576 - INFO - Loading data for Australian Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# 2025-05-05 22:45:06,578 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-05-05 22:45:06,579 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-05-05 22:45:07,119 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# 2025-05-05 22:45:07,120 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-05-05 22:45:07,122 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-05-05 22:45:07,124 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-05-05 22:45:37,587 - WARNING - Could not get/save telemetry for driver 10 in 2018_01_Australian Grand Prix_R: '10'
# 2025-05-05 22:45:37,588 - WARNING - Could not get/save telemetry for driver 9 in 2018_01_Australian Grand Prix_R: '9'
# 2025-05-05 22:45:37,589 - WARNING - Could not get/save telemetry for driver 35 in 2018_01_Australian Grand Prix_R: '35'
# 2025-05-05 22:45:37,589 - INFO - No telemetry saved for any driver in 2018_01_Australian Grand Prix_R
# 2025-05-05 22:45:37,593 - INFO - Successfully processed and saved data for 2018_01_Australian Grand Prix_R
# 2025-05-05 22:45:38,658 - INFO - Processing Event: 2018 - Round 2 - Bahrain Grand Prix
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.5.3]
# 2025-05-05 22:45:38,674 - INFO - Loading data for Bahrain Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# 2025-05-05 22:45:38,675 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-05-05 22:45:38,676 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-05-05 22:45:39,188 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# 2025-05-05 22:45:39,190 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-05-05 22:45:39,192 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-05-05 22:45:39,193 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-05-05 22:45:39,194 - INFO - Processing timing data...
# req            INFO 	Using cached data for car_data
# 2025-05-05 22:45:39,705 - INFO - Using cached data for car_data
# req            INFO 	Using cached data for position_data
# 2025-05-05 22:45:39,779 - INFO - Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# 2025-05-05 22:45:40,489 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-05-05 22:45:40,490 - INFO - Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:40,519 - INFO - Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:40,520 - INFO - Loaded basic data for 2018_02_Bahrain Grand Prix_FP1
# 2025-05-05 22:45:40,547 - INFO - Loading telemetry for 2018_02_Bahrain Grand Prix_FP1...
# 2025-05-05 22:45:41,022 - WARNING - Could not get/save telemetry for driver 2 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:41,445 - WARNING - Could not get/save telemetry for driver 3 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:41,855 - WARNING - Could not get/save telemetry for driver 5 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:42,248 - WARNING - Could not get/save telemetry for driver 7 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:42,646 - WARNING - Could not get/save telemetry for driver 8 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:40,996 - WARNING - Could not get/save telemetry for driver 9 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:41,385 - WARNING - Could not get/save telemetry for driver 10 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:41,789 - WARNING - Could not get/save telemetry for driver 11 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:42,232 - WARNING - Could not get/save telemetry for driver 14 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:42,615 - WARNING - Could not get/save telemetry for driver 16 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:42,934 - WARNING - Could not get/save telemetry for driver 18 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:43,305 - WARNING - Could not get/save telemetry for driver 20 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:43,687 - WARNING - Could not get/save telemetry for driver 27 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:44,122 - WARNING - Could not get/save telemetry for driver 28 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:44,571 - WARNING - Could not get/save telemetry for driver 31 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:44,781 - WARNING - Could not get/save telemetry for driver 33 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:45,212 - WARNING - Could not get/save telemetry for driver 35 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:45,663 - WARNING - Could not get/save telemetry for driver 44 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:46,068 - WARNING - Could not get/save telemetry for driver 55 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:46,512 - WARNING - Could not get/save telemetry for driver 77 in 2018_02_Bahrain Grand Prix_FP1: "['SessionTime'] not in index"
# 2025-05-05 22:45:46,512 - INFO - No telemetry saved for any driver in 2018_02_Bahrain Grand Prix_FP1
# 2025-05-05 22:45:46,515 - INFO - Successfully processed and saved data for 2018_02_Bahrain Grand Prix_FP1
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.5.3]
# 2025-05-05 22:45:47,543 - INFO - Loading data for Bahrain Grand Prix - Practice 2 [v3.5.3]
# req            INFO 	Using cached data for session_info
# 2025-05-05 22:45:47,544 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-05-05 22:45:47,545 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-05-05 22:45:47,558 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# 2025-05-05 22:45:47,560 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-05-05 22:45:47,563 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-05-05 22:45:47,567 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-05-05 22:45:47,568 - INFO - Processing timing data...
# core        WARNING 	Driver 77: Lap timing integrity check failed for 1 lap(s)
# 2025-05-05 22:45:48,059 - WARNING - Driver 77: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# 2025-05-05 22:45:48,178 - INFO - Using cached data for car_data
# req            INFO 	Using cached data for position_data
# 2025-05-05 22:45:48,247 - INFO - Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# 2025-05-05 22:45:48,938 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-05-05 22:45:48,940 - INFO - Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:48,965 - INFO - Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:48,965 - INFO - Loaded basic data for 2018_02_Bahrain Grand Prix_FP2
# 2025-05-05 22:45:49,010 - INFO - Loading telemetry for 2018_02_Bahrain Grand Prix_FP2...
# 2025-05-05 22:45:49,395 - WARNING - Could not get/save telemetry for driver 2 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:49,767 - WARNING - Could not get/save telemetry for driver 3 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:50,166 - WARNING - Could not get/save telemetry for driver 5 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:50,536 - WARNING - Could not get/save telemetry for driver 7 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:50,922 - WARNING - Could not get/save telemetry for driver 8 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:51,337 - WARNING - Could not get/save telemetry for driver 9 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:51,705 - WARNING - Could not get/save telemetry for driver 10 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:52,070 - WARNING - Could not get/save telemetry for driver 11 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:52,427 - WARNING - Could not get/save telemetry for driver 14 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:52,799 - WARNING - Could not get/save telemetry for driver 16 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:53,264 - WARNING - Could not get/save telemetry for driver 18 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:53,652 - WARNING - Could not get/save telemetry for driver 20 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:54,005 - WARNING - Could not get/save telemetry for driver 27 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:54,385 - WARNING - Could not get/save telemetry for driver 28 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:54,766 - WARNING - Could not get/save telemetry for driver 31 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:55,134 - WARNING - Could not get/save telemetry for driver 33 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:55,496 - WARNING - Could not get/save telemetry for driver 35 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:55,839 - WARNING - Could not get/save telemetry for driver 44 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:56,185 - WARNING - Could not get/save telemetry for driver 55 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:56,524 - WARNING - Could not get/save telemetry for driver 77 in 2018_02_Bahrain Grand Prix_FP2: "['SessionTime'] not in index"
# 2025-05-05 22:45:56,525 - INFO - No telemetry saved for any driver in 2018_02_Bahrain Grand Prix_FP2
# 2025-05-05 22:45:56,528 - INFO - Successfully processed and saved data for 2018_02_Bahrain Grand Prix_FP2
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 3 [v3.5.3]
# 2025-05-05 22:45:57,558 - INFO - Loading data for Bahrain Grand Prix - Practice 3 [v3.5.3]
# req            INFO 	Using cached data for session_info
# 2025-05-05 22:45:57,559 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-05-05 22:45:57,560 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-05-05 22:45:57,574 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# 2025-05-05 22:45:57,575 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-05-05 22:45:57,593 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-05-05 22:45:57,595 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-05-05 22:45:57,595 - INFO - Processing timing data...
# core        WARNING 	Driver 55: Lap timing integrity check failed for 1 lap(s)
# 2025-05-05 22:45:57,932 - WARNING - Driver 55: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# 2025-05-05 22:45:58,024 - INFO - Using cached data for car_data
# req            INFO 	Using cached data for position_data
# 2025-05-05 22:45:58,068 - INFO - Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# 2025-05-05 22:45:58,585 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-05-05 22:45:58,587 - INFO - Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:58,618 - INFO - Finished loading data for 20 drivers: ['2', '3', '5', '7', '8', '9', '10', '11', '14', '16', '18', '20', '27', '28', '31', '33', '35', '44', '55', '77']
# 2025-05-05 22:45:58,619 - INFO - Loaded basic data for 2018_02_Bahrain Grand Prix_FP3
# 2025-05-05 22:45:58,638 - INFO - Loading telemetry for 2018_02_Bahrain Grand Prix_FP3...
# 2025-05-05 22:45:58,949 - WARNING - Could not get/save telemetry for driver 2 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:45:59,257 - WARNING - Could not get/save telemetry for driver 3 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:45:59,544 - WARNING - Could not get/save telemetry for driver 5 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:45:59,849 - WARNING - Could not get/save telemetry for driver 7 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:00,157 - WARNING - Could not get/save telemetry for driver 8 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:00,522 - WARNING - Could not get/save telemetry for driver 9 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:00,832 - WARNING - Could not get/save telemetry for driver 10 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:01,176 - WARNING - Could not get/save telemetry for driver 11 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:01,590 - WARNING - Could not get/save telemetry for driver 14 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:01,895 - WARNING - Could not get/save telemetry for driver 16 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:02,169 - WARNING - Could not get/save telemetry for driver 18 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:02,468 - WARNING - Could not get/save telemetry for driver 20 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:02,770 - WARNING - Could not get/save telemetry for driver 27 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:03,063 - WARNING - Could not get/save telemetry for driver 28 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:03,333 - WARNING - Could not get/save telemetry for driver 31 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:03,634 - WARNING - Could not get/save telemetry for driver 33 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:03,909 - WARNING - Could not get/save telemetry for driver 35 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:04,188 - WARNING - Could not get/save telemetry for driver 44 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:04,463 - WARNING - Could not get/save telemetry for driver 55 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:04,739 - WARNING - Could not get/save telemetry for driver 77 in 2018_02_Bahrain Grand Prix_FP3: "['SessionTime'] not in index"
# 2025-05-05 22:46:04,740 - INFO - No telemetry saved for any driver in 2018_02_Bahrain Grand Prix_FP3
# 2025-05-05 22:46:04,743 - INFO - Successfully processed and saved data for 2018_02_Bahrain Grand Prix_FP3
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.5.3]
# 2025-05-05 22:46:05,817 - INFO - Loading data for Bahrain Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# 2025-05-05 22:46:05,818 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-05-05 22:46:05,819 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-05-05 22:46:06,232 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# 2025-05-05 22:46:06,233 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-05-05 22:46:06,235 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-05-05 22:46:06,237 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-05-05 22:46:06,237 - INFO - Processing timing data...
# req            INFO 	Using cached data for car_data
# 2025-05-05 22:46:06,666 - INFO - Using cached data for car_data
# req            INFO 	Using cached data for position_data
# 2025-05-05 22:46:06,715 - INFO - Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# 2025-05-05 22:46:07,280 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-05-05 22:46:07,282 - INFO - Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['5', '7', '77', '44', '3', '10', '20', '27', '31', '55', '28', '11', '14', '2', '33', '8', '9', '35', '16', '18']
# 2025-05-05 22:46:07,316 - INFO - Finished loading data for 20 drivers: ['5', '7', '77', '44', '3', '10', '20', '27', '31', '55', '28', '11', '14', '2', '33', '8', '9', '35', '16', '18']
# 2025-05-05 22:46:07,317 - INFO - Loaded basic data for 2018_02_Bahrain Grand Prix_Q
# 2025-05-05 22:46:07,334 - INFO - Loading telemetry for 2018_02_Bahrain Grand Prix_Q...
# 2025-05-05 22:46:07,663 - WARNING - Could not get/save telemetry for driver 5 in 2018_02_Bahrain Grand Prix_Q: "['SessionTime'] not in index"
# 2025-05-05 22:46:08,010 - WARNING - Could not get/save telemetry for driver 7 in 2018_02_Bahrain Grand Prix_Q: "['SessionTime'] not in index"
# 2025-05-05 22:46:08,338 - WARNING - Could not get/save telemetry for driver 77 in 2018_02_Bahrain Grand Prix_Q: "['SessionTime'] not in index"
# 2025-05-05 22:46:08,665 - WARNING - Could not get/save telemetry for driver 44 in 2018_02_Bahrain Grand Prix_Q: "['SessionTime'] not in index"
# 2025-05-05 22:46:08,982 - WARNING - Could not get/save telemetry for driver 3 in 2018_02_Bahrain Grand Prix_Q: "['SessionTime'] not in index"
# ...
# 2025-05-05 23:16:14,699 - ERROR - Could not get event schedule for 2023: Failed to load any schedule data.
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# 2025-05-05 23:16:14,949 - WARNING - Failed to load schedule from FastF1 backend!
# 2025-05-05 23:16:14,953 - DEBUG - Traceback for failure in FastF1 schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 584, in _get_schedule_ff1
#     response = Cache.requests_get(
#         _SCHEDULE_BASE_URL + f"schedule_{year}.json",
#         headers=_HEADERS
#     )
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for season_schedule. Loading data...
# 2025-05-05 23:16:14,957 - INFO - No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# 2025-05-05 23:16:14,959 - INFO - Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# 2025-05-05 23:16:15,198 - WARNING - Failed to load schedule from F1 API backend!
# 2025-05-05 23:16:15,199 - DEBUG - Traceback for failure in F1 API schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 644, in _get_schedule_from_f1_timing
#     response = fastf1._api.season_schedule(f'/static/{year}/')
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/_api.py", line 1651, in season_schedule
#     response = fetch_page(path, 'index')
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/_api.py", line 1725, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# 2025-05-05 23:16:15,450 - WARNING - Failed to load schedule from Ergast API backend!
# 2025-05-05 23:16:15,451 - DEBUG - Traceback for failure in Ergast API Schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 731, in _get_schedule_from_ergast
#     season = fastf1.ergast.fetch_season(year)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/ergast/legacy.py", line 29, in fetch_season
#     Cache.requests_get(url, headers=_headers))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# 2025-05-05 23:16:15,453 - ERROR - Could not get event schedule for 2024: Failed to load any schedule data.
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# 2025-05-05 23:16:15,691 - WARNING - Failed to load schedule from FastF1 backend!
# 2025-05-05 23:16:15,692 - DEBUG - Traceback for failure in FastF1 schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 584, in _get_schedule_ff1
#     response = Cache.requests_get(
#         _SCHEDULE_BASE_URL + f"schedule_{year}.json",
#         headers=_HEADERS
#     )
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for season_schedule. Loading data...
# 2025-05-05 23:16:15,693 - INFO - No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# 2025-05-05 23:16:15,694 - INFO - Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# 2025-05-05 23:16:15,950 - WARNING - Failed to load schedule from F1 API backend!
# 2025-05-05 23:16:15,954 - DEBUG - Traceback for failure in F1 API schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 644, in _get_schedule_from_f1_timing
#     response = fastf1._api.season_schedule(f'/static/{year}/')
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/_api.py", line 1651, in season_schedule
#     response = fetch_page(path, 'index')
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/_api.py", line 1725, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# 2025-05-05 23:16:16,201 - WARNING - Failed to load schedule from Ergast API backend!
# 2025-05-05 23:16:16,204 - DEBUG - Traceback for failure in Ergast API Schedule
# Traceback (most recent call last):
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/events.py", line 731, in _get_schedule_from_ergast
#     season = fastf1.ergast.fetch_season(year)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/ergast/legacy.py", line 29, in fetch_season
#     Cache.requests_get(url, headers=_headers))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/home/levi/f1-dash/.venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# 2025-05-05 23:16:16,207 - ERROR - Could not get event schedule for 2025: Failed to load any schedule data.
# 2025-05-05 23:16:16,208 - INFO - --- All Years Processed ---
